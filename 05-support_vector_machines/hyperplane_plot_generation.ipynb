# %%
from sklearn.datasets import make_blobs
from sklearn.svm import SVC
import numpy as np

data, target = make_blobs(n_samples=300, n_features=3, centers=2)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

colors = ['#FE4365' if x==0 else '#83AF9B' for x in target]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs=data[:,0], ys=data[:,1], zs=data[:,2],
           c=colors, edgecolors='b', linewidth=0.2)

# hide axis ticks
"""
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
ax.zaxis.set_ticks([])
"""

plt.show()

# %%
clf = SVC(kernel='linear')
clf.fit(data, target)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

z = lambda x,y: (-clf.intercept_[0]-clf.coef_[0][0]*x-clf.coef_[0][1]) / clf.coef_[0][2]

tmp = np.linspace(-2,10,51)
x,y = np.meshgrid(tmp,tmp)
ax.plot_surface(x, y, z(x,y), alpha=0.8, color='#F9CDAD')
ax.scatter(xs=data[:,0], ys=data[:,1], zs=data[:,2], 
           c=colors, edgecolors='b', linewidth=0.2)

# hide axis ticks
"""
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
ax.zaxis.set_ticks([])
"""

plt.show()

# %%
## 2d plots
data, target = make_blobs(n_samples=300, n_features=2, centers=2)

colors = ['#FE4365' if x==0 else '#83AF9B' for x in target]

plt.scatter(data[:,0], data[:,1], c=colors, edgecolors='b', linewidth=0.2)
plt.show()

# %%
clf = SVC(kernel='linear')
clf.fit(data, target)

w = clf.coef_[0]
a = -w[0] / w[1]
xx = np.linspace(-5, 5)
yy = a * xx - (clf.intercept_[0]) / w[1]

plt.scatter(data[:,0], data[:,1], c=colors, edgecolors='b', linewidth=0.2)
plt.plot(xx, yy, 'k-', color='#937966')
plt.show()
